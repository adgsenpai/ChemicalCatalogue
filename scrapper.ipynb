# %%
from pptx import Presentation
import pandas as pd

# Open PulpanPaperDataOnly.pptx
prs = Presentation('./data/PulpanPaperDataOnly.pptx')
data = []

for i in range(len(prs.slides)):
    slide = prs.slides[i]
    title = slide.shapes.title.text    
    if slide.shapes[0].text == 'General':
        equipment = slide.shapes[2].text.split(',')
    else:
        equipment = slide.shapes[0].text.split(',')
    # remove cont. and also AND words
    equipment = [item.replace('cont.', '') for item in equipment]
    equipment = [item.replace('and', ',') for item in equipment]
    equipment = [item.replace('/', ',') for item in equipment]    
    # account for ()
    equipment = [item.replace('(', '') for item in equipment]
    equipment = [item.replace(')', '') for item in equipment]

    # remove spaces in front of , / or and
    equipment = [item.strip() for item in equipment]
    # remove / with ,
    equipment = [item.lstrip() for item in equipment]
    equipment = [item.replace(' , ', ",") for item in equipment]
    # check if text got , in it then seperate it
    equipment = [item.lstrip() for item in equipment]
    
    
    for item in equipment:
        # if item has ,
        if ',' in item:
            # split it
            equipment.extend(item.split(','))
            # remove the item with ,
            equipment.remove(item)         

    # Initialize a variable for the table
    table = None

    # Iterate through shapes to find a table
    for shape in slide.shapes:
        if shape.has_table:
            table = shape.table
            break


    if table is not None: 
        for i, row in enumerate(table.rows):
            if i == 0:
                continue
            else:             
                row_data = {
                    'Industry': title,
                    'Equipment': equipment,        
                    'Component Part': row.cells[0].text.strip(),
                    'Lube Spec': row.cells[1].text.strip(),
                    'Lube Requirements': row.cells[2].text.strip(),
                    'Standard': row.cells[3].text.strip(),
                    'Premium': row.cells[4].text.strip(),
                    'Supreme': row.cells[5].text.strip(),
                }
                if (row_data['Component Part'] == '') and (row_data['Lube Spec'] == '') and (row_data['Lube Requirements'] == ''):
                    continue
                else:
                    data.append(row_data)       
               

# Now, 'data' contains the extracted information without duplicates
data
# Out:
# [{'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Converter',
#   'Lube Spec': 'SAE 30\nTO-4 series',
#   'Lube Requirements': 'Long drain intervals\nHigh temperature handling\nHigh load capability',
#   'Standard': 'PETRONAS Powertrans T4 30W',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Engine',
#   'Lube Spec': 'Engine Oil 15W40 / 10W40',
#   'Lube Requirements': 'Cold starting\nLong idling periods\nSoot handling',
#   'Standard': 'PETRONAS Urania LD 7 **',
#   'Premium': 'PETRONAS Urania 5000 E 15W40 **',
#   'Supreme': 'PETRONAS Urania 7000 E 10W40 **'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Cooling System',
#   'Lube Spec': 'Coolant Fluid',
#   'Lube Requirements': 'Long periods of work\nHigh temperature',
#   'Standard': 'PETRONAS Paraflu 11 **',
#   'Premium': 'PETRONAS Paraflu Up Ready **',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Final Drive',
#   'Lube Spec': 'SAE 50\nTO-4 series',
#   'Lube Requirements': 'Long drain intervals\nHigh temperature handling\nHigh load capability',
#   'Standard': 'PETRONAS Powertrans T4 50W **',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Grease points',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'With solid lubricants\nWater tolerance\nHigh load capability',
#   'Standard': 'PETRONAS Grease LiX MEP',
#   'Premium': 'PETRONAS Grease LiCa MG HL',
#   'Supreme': 'PETRONAS Grease LiCa MG XHL'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Hydraulics / Steering',
#   'Lube Spec': 'SAE 10W\nTO-4 series',
#   'Lube Requirements': 'Long drain intervals\nHigh temperature handling\nHigh load capability',
#   'Standard': 'PETRONAS Powertrans T4 10W **',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Dump Truck', 'Wheel Loaders', 'Front End Loaders'],
#   'Component Part': 'Transmission',
#   'Lube Spec': 'SAE 30\nTO-4 series',
#   'Lube Requirements': 'Long drain intervals\nHigh temperature handling\nHigh load capability',
#   'Standard': 'PETRONAS Powertrans T4 30W',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life\nHalogen free',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Engine',
#   'Lube Spec': 'Engine Oil 15W40 / 10W40',
#   'Lube Requirements': 'Cold starting\nLong idling periods\nSoot handling\nHalogen free',
#   'Standard': 'PETRONAS Urania LD 7 **',
#   'Premium': 'PETRONAS Urania 5000 E 15W40 **',
#   'Supreme': 'PETRONAS Urania 7000 E 10W40 **'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Cooling System',
#   'Lube Spec': 'Coolant Fluid',
#   'Lube Requirements': 'Long periods of work\nHigh temperature',
#   'Standard': 'PETRONAS Paraflu 11 **',
#   'Premium': 'PETRONAS Paraflu Up Ready **',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability\nHalogen free',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Open Gears',
#   'Lube Spec': 'AGMA 251.01\nFZG\nUS Steel',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure\nLow consumption\nHalogen free',
#   'Standard': '',
#   'Premium': 'PETRONAS Grease LiCa TMG',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Cables  / Wire Ropes',
#   'Lube Spec': 'OIPEEC',
#   'Lube Requirements': 'Core penetration\nAdhesive characteristics\nElasticity\nRust and corrosion protection\nHalogen free',
#   'Standard': 'PETRONAS Grease LiCa GEP 2.5',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed\nInert lubricant\nHalogen free',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68',
#   'Lube Requirements': 'High viscosity index\nWater and dust tolerance\nWater separability\nHalogen free',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF )'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Hydraulics (Mobile)',
#   'Lube Spec': 'SAE 10W\nTO-4 series',
#   'Lube Requirements': 'Long drain intervals\nHigh temperature handling\nHigh load capability\nHalogen free',
#   'Standard': 'PETRONAS Powertrans T4 10W **',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Chains / Sprockets',
#   'Lube Spec': 'Spray or Grease Lubricants',
#   'Lube Requirements': 'Aerosol form\nPenetrate and have tackifier\nHalogen free',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Cranes', 'Lifting Equipment'],
#   'Component Part': 'Slides and Rails\n(large quantities)',
#   'Lube Spec': 'Spray or Grease Lubricants (Preserve equip)',
#   'Lube Requirements': 'Aerosol form\nPenetrate and have tackifier\nSolid lubricants (grease)\nHalogen free',
#   'Standard': 'No product available\n(Li 000)',
#   'Premium': '',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Bearings (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nExtreme water tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Coupling',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Chains',
#   'Lube Spec': '',
#   'Lube Requirements': '',
#   'Standard': 'No lubrication required',
#   'Premium': '',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Logging Deck', 'Sorter'],
#   'Component Part': 'Chain drive',
#   'Lube Spec': 'ISO VG 68 and 220\nCincinnati Machine Spec',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Bearings (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Open Gears',
#   'Lube Spec': 'AGMA 251.01\nFZG\nUS Steel',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure\nLow consumption',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease LiCa TMG',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP*',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Coupling (grease)',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Coupling (oil)',
#   'Lube Spec': 'ISO VG 46',
#   'Lube Requirements': 'Oxidation stability\nGood air release\nLow foaming tendencies',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Support rolls',
#   'Lube Spec': '',
#   'Lube Requirements': 'Dry lubricant required (Graphite Blocks)\nCan use waste lubricant (gear or hydraulic oil)',
#   'Standard': 'No product available',
#   'Premium': '',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68\nHigh viscosity index',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Debarking Drum'],
#   'Component Part': 'Chain drive',
#   'Lube Spec': 'ISO VG 68 and 220\nCincinnati Machine Spec',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP*',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Coupling (oil)',
#   'Lube Spec': 'ISO VG 46',
#   'Lube Requirements': 'Oxidation stability\nGood air release\nLow foaming tendencies',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Coupling (grease)',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68\nHigh viscosity index',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Chipper'],
#   'Component Part': 'Grease points',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'Water tolerance\nHigh load capability',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Screener', 'Slicer'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Screener', 'Slicer'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP*',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Screener', 'Slicer'],
#   'Component Part': 'Chains / Sprockets (CLS system)',
#   'Lube Spec': 'ISO VG 68 and 220\nCincinnati Machine Spec',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Screener', 'Slicer'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard - Transfers',
#   'Equipment': ['Conveyor'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard - Transfers',
#   'Equipment': ['Conveyor'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard - Transfers',
#   'Equipment': ['Conveyor'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard - Transfers',
#   'Equipment': ['Conveyor'],
#   'Component Part': 'Couplings',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard - Transfers',
#   'Equipment': ['Conveyor'],
#   'Component Part': 'Conveyor Back stop',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': '',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Open Gears',
#   'Lube Spec': 'AGMA 251.01\nFZG\nUS Steel',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure\nLow consumption',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease LiCa TMG',
#   'Supreme': ''},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Cables',
#   'Lube Spec': 'OIPEEC',
#   'Lube Requirements': 'Core penetration\nAdhesive characteristics\nElasticity\nRust and corrosion protection',
#   'Standard': 'PETRONAS Grease LiCa GEP 2.5',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68',
#   'Lube Requirements': 'High viscosity index\nWater and dust tolerance\nWater separability',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Slewing Ring Bearing',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Extreme load\nWhite solids\nThermal and oxidation stability',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Grease LiX  2/600 SR'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Stacker', 'Re-claimer'],
#   'Component Part': 'Reclaimer Chains',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nExtreme water tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Pulp Chip Bins', 'Silos'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Pulp Chip Bins', 'Silos'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Woodyard',
#   'Equipment': ['Pulp Chip Bins', 'Silos'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Chip steaming vessel'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Grease LiX Syn 1/1500'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Chip steaming vessel'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Chip steaming vessel'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Chip steaming vessel'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68\nHigh viscosity index',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Chip steaming vessel'],
#   'Component Part': 'Grease points',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'Water tolerance\nHigh load capability',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Digester'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Grease LiX Syn 1/1500'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Digester'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Digester'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Digester'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68\nHigh viscosity index',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Digester'],
#   'Component Part': 'Grease points',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'Water tolerance\nHigh load capability',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Digester Blow Tanks'],
#   'Component Part': 'No lubrication',
#   'Lube Spec': '',
#   'Lube Requirements': '',
#   'Standard': '',
#   'Premium': '',
#   'Supreme': ''},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Washer'],
#   'Component Part': 'Bearings (Oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': 'PETRONAS Circula PM',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Washer'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Washer'],
#   'Component Part': 'Re-pulper and General Bearings  (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Washer'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Bleaching Towers'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Bleaching Towers'],
#   'Component Part': 'Bearings  (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Pulp Bleaching Towers'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Screw type Pulp Press', 'Screw Conveyor'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Screw type Pulp Press', 'Screw Conveyor'],
#   'Component Part': 'Bearings  (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Screw type Pulp Press', 'Screw Conveyor'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Double Belt Pulp Press'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Double Belt Pulp Press'],
#   'Component Part': 'Bearings  (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Pulp Mill',
#   'Equipment': ['Double Belt Pulp Press'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Pulp Storage Pumps', 'Agitators'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': 'Syn',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Pulp Storage Pumps', 'Agitators'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Pulp Storage Pumps', 'Agitators'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Re-pulper'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Re-pulper'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Re-pulper'],
#   'Component Part': 'Coupling (grease)',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Re-pulper'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Mixing', 'Machine Chests'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Mixing', 'Machine Chests'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refiners'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refiners'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refiners'],
#   'Component Part': 'Geared Coupling (Grease)',
#   'Lube Spec': 'NLGI 1\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refiners'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refiners'],
#   'Component Part': 'Bearings (Oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refined stock chest'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Stock Preparation',
#   'Equipment': ['Refined stock chest'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Wire Roll Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Press Roll Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Rope Pulley Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Fans – Trim (grease)',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Vacuum Pumps (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease CaSX'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Rewind Stand Bearings  (Pope Reel)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Calendar Roll Bearings  (Oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': 'PETRONAS Circula PM',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutter',
#    'Conveyers Underfloor',
#    ' Above Floor'],
#   'Component Part': 'Roll Drive Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Fans – Hood (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Fans (oil)',
#   'Lube Spec': 'ISO VG 46',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': 'PETRONAS Circula PM',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Hydraulics (stationary)',
#   'Lube Spec': 'ISO VG 46 / 68\nHigh viscosity index',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Dryer Bearings (Oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': 'PETRONAS Circula PM',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Papermaking',
#   'Equipment': ['Paper Machine Wet End',
#    'Drying',
#    'Calendaring',
#    'Winding',
#    'Roll & Sheet Cutters'],
#   'Component Part': 'Steam Rotary Joints',
#   'Lube Spec': 'NLGI 2 EP\nSolid lubricants (Moly)',
#   'Lube Requirements': 'Water tolerance\nAntiwear properties\nHigh temperature',
#   'Standard': 'PETRONAS Grease LiX MEP',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Girth Gear',
#   'Lube Spec': 'AGMA 251.01\nFZG\nUS Steel',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure\nLow consumption',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease LiCa TMG',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Thrust Bearings',
#   'Lube Spec': 'ISO VG 1000',
#   'Lube Requirements': 'Lubricity\nHigh load capability\nOxidation resistance\nAnti-wear',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Circula Syn PAO 1000'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Kiln Support Roller Bearings',
#   'Lube Spec': 'ISO VG 1000',
#   'Lube Requirements': 'Lubricity\nHigh load capability\nOxidation resistance\nAnti-wear',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Circula Syn PAO 1000'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Auxiliary Diesel Engine',
#   'Lube Spec': 'Engine Oil 15W40 / 10W40',
#   'Lube Requirements': 'Cold starting\nLong idling periods\nSoot handling',
#   'Standard': 'PETRONAS Urania LD 7 **',
#   'Premium': 'PETRONAS Urania 5000 E 15W40 **',
#   'Supreme': 'PETRONAS Urania 7000 E 10W40 **'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Cooling System',
#   'Lube Spec': 'Coolant Fluid',
#   'Lube Requirements': 'Long periods of work\nHigh temperature',
#   'Standard': 'PETRONAS Paraflu 11 **',
#   'Premium': 'PETRONAS Paraflu Up Ready **',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Auxiliary Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Electric Motor - Grease',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Drive Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP*',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Couplings',
#   'Lube Spec': 'NLGI 2 EP\nAGMA CG 1 and 2',
#   'Lube Requirements': 'Low oil bleed\nOxidation stability\nResistance to centrifugal force',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PE HS',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Rotary Lime Kiln'],
#   'Component Part': 'Live Ring',
#   'Lube Spec': '',
#   'Lube Requirements': '',
#   'Standard': 'No Product / Graphite Powder',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Forced Draught Fan Bearings  (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-Petronas Grease Li EP 2',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Forced Draught Fan Bearings  (oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Induced Draught Fan Bearings  (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Induced Draught Fan Bearings  (oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Circula',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Circula Syn'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Primary Air Fan Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Secondary Air Fan Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/100'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Soot blower Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'High temperature\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Gear Syn PAG'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Precipitator Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'Chemical Recovery Plant',
#   'Equipment': ['Recovery Boiler'],
#   'Component Part': 'Precipitator support bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': '-',
#   'Premium': 'PETRONAS Grease CaSX',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'Water management & treatment',
#   'Equipment': ['Clarifiers', 'Filtration'],
#   'Component Part': 'Bearings',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease LiX EP 2/380',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/460'},
#  {'Industry': 'Water management & treatment',
#   'Equipment': ['Clarifiers', 'Filtration'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': '-',
#   'Premium': '-',
#   'Supreme': 'PETRONAS Gear Syn WI'},
#  {'Industry': 'Water management & treatment',
#   'Equipment': ['Clarifiers', 'Filtration'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Water management & treatment',
#   'Equipment': ['Clarifiers', 'Filtration'],
#   'Component Part': 'Chains',
#   'Lube Spec': 'ISO VG 220\nCincinnati Machine Spec',
#   'Lube Requirements': 'Tackiness\nRust and corrosion protection\nLubricity',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '-',
#   'Supreme': '-'},
#  {'Industry': 'Water management & treatment',
#   'Equipment': ['Clarifiers', 'Filtration'],
#   'Component Part': 'Pumps',
#   'Lube Spec': 'ISO VG  68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Power Generation',
#   'Equipment': ['Turbines'],
#   'Component Part': 'Turbine bearings',
#   'Lube Spec': 'ISO VG  46/68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'Power Generation',
#   'Equipment': ['Turbines'],
#   'Component Part': 'Turbine gear drive',
#   'Lube Spec': 'ISO VG  46/68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'Power Generation',
#   'Equipment': ['Turbines'],
#   'Component Part': 'Pumps',
#   'Lube Spec': 'ISO VG  68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'Power Generation',
#   'Equipment': ['Turbines'],
#   'Component Part': 'Generator bearings (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'Power Generation',
#   'Equipment': ['Turbines'],
#   'Component Part': 'Generator bearings (oil)',
#   'Lube Spec': 'ISO VG  46/68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'General',
#   'Equipment': ['Blowers'],
#   'Component Part': 'Bearings  (grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': 'PETRONAS Grease CaSx',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'General',
#   'Equipment': ['Blowers'],
#   'Component Part': 'Gearbox / Reducer / Bearings (oil)',
#   'Lube Spec': 'AGMA 4-7 EP',
#   'Lube Requirements': 'Micropitting resistance\nHigh load capability\nLow foaming tendencies\nWater separability',
#   'Standard': 'PETRONAS Gear MEP *',
#   'Premium': 'PETRONAS Gear FL',
#   'Supreme': 'PETRONAS Gear Syn PAO'},
#  {'Industry': 'General',
#   'Equipment': ['Blowers'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Pumps'],
#   'Component Part': 'Bearings (Oil)',
#   'Lube Spec': 'ISO VG  68',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF )'},
#  {'Industry': 'General',
#   'Equipment': ['Pumps'],
#   'Component Part': 'Bearings (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nWater tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': 'PETRONAS Grease CaSx',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'General',
#   'Equipment': ['Pumps'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Air Compressors'],
#   'Component Part': 'Air compressor',
#   'Lube Spec': '51506-VDL',
#   'Lube Requirements': 'Oxidation stability\nGood air release\nFoam tendencies',
#   'Standard': 'PETRONAS Compressor A M2',
#   'Premium': 'PETRONAS Compressor A M4',
#   'Supreme': 'PETRONAS Compressor A Syn PAO'},
#  {'Industry': 'General',
#   'Equipment': ['Air Compressors'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Bearings (Grease)',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'High load capability\nExtreme water tolerance\nLong life',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Bearings (Oil)',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Diesel Engine Oil',
#   'Lube Spec': 'Engine Oil 15W40 / 10W40',
#   'Lube Requirements': 'Cold starting\nLong idling periods\nSoot handling',
#   'Standard': 'PETRONAS Urania LD 7 **',
#   'Premium': 'PETRONAS Urania 5000 E 15W40 **',
#   'Supreme': 'PETRONAS Urania 7000 E 10W40 **'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Cooling System',
#   'Lube Spec': 'Coolant Fluid',
#   'Lube Requirements': 'Long periods of work\nHigh temperature',
#   'Standard': 'PETRONAS Paraflu 11 **',
#   'Premium': 'PETRONAS Paraflu Up Ready **',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Electric Motor Bearings',
#   'Lube Spec': 'NLGI 2',
#   'Lube Requirements': 'Long life at high temperature\nLow bleed\nMedium and high speed',
#   'Standard': 'PETRONAS Grease Li 2',
#   'Premium': 'PETRONAS Grease PU',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Gas Turbine',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'General',
#   'Equipment': ['Back Up Generators - Diesel & Gas Turbine'],
#   'Component Part': 'Gearbox / Reducer',
#   'Lube Spec': 'ISO VG range',
#   'Lube Requirements': 'Demulsibity\nLow foaming tendencies\nAntiwear properties',
#   'Standard': 'PETRONAS Jenteram',
#   'Premium': 'PETRONAS Jenteram G',
#   'Supreme': 'PETRONAS Jenteram Syn'},
#  {'Industry': 'General',
#   'Equipment': ['Machinery Workshops'],
#   'Component Part': 'Cutting fluids',
#   'Lube Spec': '',
#   'Lube Requirements': 'High emulsion stability\nExcellent lubricity and anti-weld\nAnti-rust, anti-corrosion\nAnti-sludge\nAnti-bacterial',
#   'Standard': 'Mecafluid SM 59 **',
#   'Premium': 'Mecafluid S 2006 **',
#   'Supreme': '-'},
#  {'Industry': 'General',
#   'Equipment': ['Machinery Workshops'],
#   'Component Part': 'Grease points',
#   'Lube Spec': 'NLGI 2 EP',
#   'Lube Requirements': 'Water tolerance\nHigh load capability',
#   'Standard': 'PETRONAS Grease Li EP 2',
#   'Premium': '',
#   'Supreme': 'PETRONAS Grease LiX Syn 2/220'},
#  {'Industry': 'General',
#   'Equipment': ['Machinery Workshops'],
#   'Component Part': 'Hydraulics',
#   'Lube Spec': 'ISO VG range \nHM specification',
#   'Lube Requirements': 'Good air release\nWater separability\nLow foaming tendencies',
#   'Standard': 'PETRONAS Hydraulic',
#   'Premium': 'PETRONAS Hydraulic HV',
#   'Supreme': 'PETRONAS Hydraulic ESF'},
#  {'Industry': 'General',
#   'Equipment': ['Machinery Workshops'],
#   'Component Part': 'Slide way oils',
#   'Lube Spec': 'ISO VG 68 and 220\nCincinnati Machine Spec',
#   'Lube Requirements': 'Pumpability and sprayability\nAdhesive characteristics\nExtreme pressure',
#   'Standard': 'PETRONAS Slideway',
#   'Premium': '-',
#   'Supreme': '-'}]

# %%
# data
df = pd.DataFrame(data)
df
# save to PulpAndPaperJSON
df.to_json('./data/PulpAndPaperJSON.json', orient='records')
# Out:
#      Industry                                       Equipment  \
# 0    Woodyard  [Dump Truck, Wheel Loaders, Front End Loaders]
# 1    Woodyard  [Dump Truck, Wheel Loaders, Front End Loaders]
# 2    Woodyard  [Dump Truck, Wheel Loaders, Front End Loaders]
# 3    Woodyard  [Dump Truck, Wheel Loaders, Front End Loaders]
# 4    Woodyard  [Dump Truck, Wheel Loaders, Front End Loaders]
# ..        ...                                             ...
# 158   General     [Back Up Generators - Diesel & Gas Turbine]
# 159   General                           [Machinery Workshops]
# 160   General                           [Machinery Workshops]
# 161   General                           [Machinery Workshops]
# 162   General                           [Machinery Workshops]
#
#         Component Part                                   Lube Spec  \
# 0            Converter                         SAE 30\nTO-4 series
# 1               Engine                    Engine Oil 15W40 / 10W40
# 2       Cooling System                               Coolant Fluid
# 3          Final Drive                         SAE 50\nTO-4 series
# 4        Grease points                                   NLGI 2 EP
# ..                 ...                                         ...
# 158  Gearbox / Reducer                                ISO VG range
# 159     Cutting fluids
# 160      Grease points                                   NLGI 2 EP
# 161         Hydraulics             ISO VG range \nHM specification
# 162     Slide way oils  ISO VG 68 and 220\nCincinnati Machine Spec
#
#                                      Lube Requirements  \
# 0    Long drain intervals\nHigh temperature handlin...
# 1    Cold starting\nLong idling periods\nSoot handling
# 2               Long periods of work\nHigh temperature
# 3    Long drain intervals\nHigh temperature handlin...
# 4    With solid lubricants\nWater tolerance\nHigh l...
# ..                                                 ...
# 158  Demulsibity\nLow foaming tendencies\nAntiwear ...
# 159  High emulsion stability\nExcellent lubricity a...
# 160              Water tolerance\nHigh load capability
# 161  Good air release\nWater separability\nLow foam...
# 162  Pumpability and sprayability\nAdhesive charact...
#
#                           Standard                          Premium  \
# 0       PETRONAS Powertrans T4 30W                                -
# 1          PETRONAS Urania LD 7 **  PETRONAS Urania 5000 E 15W40 **
# 2           PETRONAS Paraflu 11 **     PETRONAS Paraflu Up Ready **
# 3    PETRONAS Powertrans T4 50W **                                -
# 4          PETRONAS Grease LiX MEP       PETRONAS Grease LiCa MG HL
# ..                             ...                              ...
# 158              PETRONAS Jenteram              PETRONAS Jenteram G
# 159             Mecafluid SM 59 **              Mecafluid S 2006 **
# 160        PETRONAS Grease Li EP 2
# 161             PETRONAS Hydraulic            PETRONAS Hydraulic HV
# 162              PETRONAS Slideway                                -
#
#                              Supreme
# 0                                  -
# 1    PETRONAS Urania 7000 E 10W40 **
# 2                                  -
# 3                                  -
# 4        PETRONAS Grease LiCa MG XHL
# ..                               ...
# 158            PETRONAS Jenteram Syn
# 159                                -
# 160    PETRONAS Grease LiX Syn 2/220
# 161           PETRONAS Hydraulic ESF
# 162                                -
#
# [163 rows x 8 columns]
